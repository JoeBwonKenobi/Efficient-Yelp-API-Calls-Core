# %% [markdown]
# # **Efficient Yelp API Calls**

# %% [markdown]
# Joe Lardie
#
# Feb 2023

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open('/Users/davyd/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
#login['API Key']

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %% [markdown]
# # **Defining Search Terms**

# %%
# set our API call parameters and filename before the first call
location = 'Grand Haven, Mi 49417'
term = 'indian'

# %%
location.split(',')[0]
# Out:
# 'Grand Haven'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Grand Haven-indian.json already exists.

# %%
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 23

# %%
results['region']
# Out:
# {'center': {'longitude': -86.21864318847656, 'latitude': 43.05206974479556}}

# %%
results['businesses']
# Out:
# [{'id': '0pdd7dgAWqHVF17Qpj6zpQ',
#   'alias': 'cumin-fresh-indian-kitchen-grand-haven-2',
#   'name': 'Cumin Fresh Indian Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/132Cz0QPphr4amENWT-gwQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cumin-fresh-indian-kitchen-grand-haven-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 90,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 43.044243, 'longitude': -86.214143},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '1106 Robins Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Grand Haven',
#    'zip_code': '49417',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['1106 Robins Rd', 'Grand Haven, MI 49417']},
#   'phone': '+16164147591',
#   'display_phone': '(616) 414-7591',
#   'distance': 943.9983326563982},
#  {'id': 'KZDRLMbnf-vPHEfiQMG6QA',
#   'alias': 'cumin-fresh-indian-kitchen-grand-haven-3',
#   'name': 'Cumin Fresh Indian Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rbWqXDO2oTVMexKY6XCWdA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cumin-fresh-indian-kitchen-grand-haven-3?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 43.0442582084732,
#    'longitude': -86.2177405440818},
#   'transactions': ['pickup'],
#   'location': {'address1': '1106 Robbins Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Grand Haven',
#    'zip_code': '49417',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['1106 Robbins Rd', 'Grand Haven, MI 49417']},
#   'phone': '+16164147591',
#   'display_phone': '(616) 414-7591',
#   'distance': 871.693627472389},
#  {'id': 'ndCJfRFJ-FXv7oil2LVcwQ',
#   'alias': 'curry-kitchen-muskegon',
#   'name': 'Curry Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ykZIbe-sT4mkQy-xIevd0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/curry-kitchen-muskegon?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 158,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.2315826416016,
#    'longitude': -86.2491836547852},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1133 3rd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Muskegon',
#    'zip_code': '49441',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['1133 3rd St', 'Muskegon, MI 49441']},
#   'phone': '+12315719777',
#   'display_phone': '(231) 571-9777',
#   'distance': 20114.11238762658},
#  {'id': 'TUTlORrbycnmJ2qteCnxEw',
#   'alias': 'naan-pizza-muskegon',
#   'name': 'Naan Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pUjlIKjflMJhsqGBw16vfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/naan-pizza-muskegon?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 7,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 43.2318587808138,
#    'longitude': -86.2495298311114},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '1131 3rd St',
#    'address2': '',
#    'address3': None,
#    'city': 'Muskegon',
#    'zip_code': '49441',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['1131 3rd St', 'Muskegon, MI 49441']},
#   'phone': '+12315719777',
#   'display_phone': '(231) 571-9777',
#   'distance': 20148.057514418735},
#  {'id': 'Xqtu6fu0tjy_phPO3rm-_Q',
#   'alias': 'pind-indian-cuisine-grand-rapids-2',
#   'name': 'Pind Indian Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5fzDMm9RCtZuwOVyaG88yQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pind-indian-cuisine-grand-rapids-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 134,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.96338933, 'longitude': -85.674373},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '241 Fulton St W',
#    'address2': '',
#    'address3': None,
#    'city': 'Grand Rapids',
#    'zip_code': '49503',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['241 Fulton St W', 'Grand Rapids, MI 49503']},
#   'phone': '+16168054767',
#   'display_phone': '(616) 805-4767',
#   'distance': 45338.760827375714},
#  {'id': '6KrPfYLp7EHWXDEGzuA49Q',
#   'alias': 'indian-masala-grand-rapids',
#   'name': 'Indian Masala',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m2jQ6gtXq-LaWAwDOyUa9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/indian-masala-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 114,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.91316, 'longitude': -85.52663},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5769 28th St SE',
#    'address2': None,
#    'address3': '',
#    'city': 'Grand Rapids',
#    'zip_code': '49546',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['5769 28th St SE', 'Grand Rapids, MI 49546']},
#   'phone': '+16162597394',
#   'display_phone': '(616) 259-7394',
#   'distance': 58464.75427602468},
#  {'id': 'ZA6XOfhfgFSOGILxvXto1g',
#   'alias': 'mithu-sri-lankan-and-indian-cuisine-grand-rapids',
#   'name': 'Mithu Sri Lankan & Indian Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YMcS-zoj3cKeK7ApzXTQsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mithu-sri-lankan-and-indian-cuisine-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 54,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'srilankan', 'title': 'Sri Lankan'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 42.8850439571692,
#    'longitude': -85.62632173558183},
#   'transactions': ['delivery'],
#   'location': {'address1': '4309 Kalamazoo Ave SE',
#    'address2': None,
#    'address3': '',
#    'city': 'Grand Rapids',
#    'zip_code': '49508',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['4309 Kalamazoo Ave SE', 'Grand Rapids, MI 49508']},
#   'phone': '+16169565098',
#   'display_phone': '(616) 956-5098',
#   'distance': 51648.473921294615},
#  {'id': 'Rap8_CEtSey5Az4FnCtoVg',
#   'alias': 'palace-of-india-grand-rapids-3',
#   'name': 'Palace of India',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9TvKVUQ0Pt6V01kvyn-vww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/palace-of-india-grand-rapids-3?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 156,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.9628487, 'longitude': -85.6649094},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '138 Fulton St E',
#    'address2': '',
#    'address3': '',
#    'city': 'Grand Rapids',
#    'zip_code': '49503',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['138 Fulton St E', 'Grand Rapids, MI 49503']},
#   'phone': '+16169139000',
#   'display_phone': '(616) 913-9000',
#   'distance': 46100.424687008635},
#  {'id': 'QN8QMDuk9sjA61GyVAs_Fw',
#   'alias': 'curry-leaf-grand-rapids',
#   'name': 'Curry Leaf',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RZe3IrmuIiZA7DZ9Vg39Rw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/curry-leaf-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 184,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.883418302206, 'longitude': -85.610281142897},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2222 44th St SE',
#    'address2': '',
#    'address3': '',
#    'city': 'Grand Rapids',
#    'zip_code': '49508',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['2222 44th St SE', 'Grand Rapids, MI 49508']},
#   'phone': '+16162814452',
#   'display_phone': '(616) 281-4452',
#   'distance': 52932.761601865706},
#  {'id': '2XT4I_AVi2-tC_Ys7PsfXA',
#   'alias': 'karki-restaurant-and-bar-grand-rapids',
#   'name': 'Karki Restaurant & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/88_EUDaWOh172tbE8KvBEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/karki-restaurant-and-bar-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 12,
#   'categories': [{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'},
#    {'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.88382960589625,
#    'longitude': -85.60887028428331},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '2293 44th St SE',
#    'address2': '',
#    'address3': None,
#    'city': 'Grand Rapids',
#    'zip_code': '49508',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['2293 44th St SE', 'Grand Rapids, MI 49508']},
#   'phone': '+16165511765',
#   'display_phone': '(616) 551-1765',
#   'distance': 53023.817720292776},
#  {'id': 'rpJga5N1UMKt6-_z8egtXw',
#   'alias': 'desi-spice-kentwood-2',
#   'name': 'Desi Spice',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0jVjz7ZhmzH8tMI8WgGk-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/desi-spice-kentwood-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 53,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.881511, 'longitude': -85.60824},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '4445D Breton Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Kentwood',
#    'zip_code': '49508',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['4445D Breton Rd', 'Kentwood, MI 49508']},
#   'phone': '+16164273728',
#   'display_phone': '(616) 427-3728',
#   'distance': 53164.10466844897},
#  {'id': 'B0HGwB6jQwJns8e90Qt90Q',
#   'alias': 'little-africa-grand-rapids',
#   'name': 'Little Africa',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YHTw28FYQJyus7sqVYjgTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-africa-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 141,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#    {'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.96255, 'longitude': -85.64509},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '956 E Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Grand Rapids',
#    'zip_code': '49503',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['956 E Fulton St', 'Grand Rapids, MI 49503']},
#   'phone': '+16162221169',
#   'display_phone': '(616) 222-1169',
#   'distance': 47687.553105624764},
#  {'id': 'kBZCdKEQmi7rL8nL_yjgQw',
#   'alias': 'curry-kitchen-gr-grand-rapids',
#   'name': 'Curry Kitchen GR',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GHTw4Mlvo4ES3KABIuUu1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/curry-kitchen-gr-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 157,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.99496, 'longitude': -85.67512},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '270 Ann St NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Grand Rapids',
#    'zip_code': '49504',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['270 Ann St NW', 'Grand Rapids, MI 49504']},
#   'phone': '+16163637748',
#   'display_phone': '(616) 363-7748',
#   'distance': 44670.98315299236},
#  {'id': 'GciiG0m-yRT5auUYBmyDGg',
#   'alias': 'india-town-grand-rapids',
#   'name': 'India Town',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yjaSbLsdh11g7Gnu-r9cRw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/india-town-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 80,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.895907753757264,
#    'longitude': -85.66497347646195},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3760 Division Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'Grand Rapids',
#    'zip_code': '49548',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['3760 Division Ave S', 'Grand Rapids, MI 49548']},
#   'phone': '+16162431219',
#   'display_phone': '(616) 243-1219',
#   'distance': 48275.891559335665},
#  {'id': 'E1Otf4z6OCsw7B4JSKZn_A',
#   'alias': 'grand-indian-cuisine-grand-rapids',
#   'name': 'Grand Indian Cuisine',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grand-indian-cuisine-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 10,
#   'categories': [{'alias': 'kebab', 'title': 'Kebab'},
#    {'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.91228659999999,
#    'longitude': -85.63516249999999},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '1280 28th St SE',
#    'address2': None,
#    'address3': None,
#    'city': 'Grand Rapids',
#    'zip_code': '49508',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['1280 28th St SE', 'Grand Rapids, MI 49508']},
#   'phone': '+16167346197',
#   'display_phone': '(616) 734-6197',
#   'distance': 49944.05279668655},
#  {'id': 'zdB3yM-2j6SROhuOZzcKEA',
#   'alias': 'pals-indian-cuisine-kentwood',
#   'name': "Pal's Indian Cuisine",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CD3EYknNYqHdbHczYsfcqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pals-indian-cuisine-kentwood?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 113,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.913036, 'longitude': -85.596093},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2887 28th St SE',
#    'address2': '',
#    'address3': '',
#    'city': 'Kentwood',
#    'zip_code': '49512',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['2887 28th St SE', 'Kentwood, MI 49512']},
#   'phone': '+16169572271',
#   'display_phone': '(616) 957-2271',
#   'distance': 52948.91489383523},
#  {'id': 'xj4OAljKp5QvEzUt-RSkZA',
#   'alias': 'steak-and-spice-by-curry-kitchen-grand-rapids',
#   'name': 'Steak & Spice By Curry Kitchen',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/steak-and-spice-by-curry-kitchen-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 42.912011357802115,
#    'longitude': -85.52573812944775},
#   'transactions': [],
#   'location': {'address1': '5700 28th St SE',
#    'address2': '',
#    'address3': '',
#    'city': 'Grand Rapids',
#    'zip_code': '49546',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['5700 28th St SE', 'Grand Rapids, MI 49546']},
#   'phone': '+16169571775',
#   'display_phone': '(616) 957-1775',
#   'distance': 58477.147042828175},
#  {'id': '9Ol1HLkbMOBmuzgbDGVILA',
#   'alias': 'le-kabob-kentwood-3',
#   'name': 'Le Kabob',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9oZqptq2HGo0y7K713S7SQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/le-kabob-kentwood-3?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 266,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'mideastern', 'title': 'Middle Eastern'},
#    {'alias': 'halal', 'title': 'Halal'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.9120920396257,
#    'longitude': -85.5906723439693},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3122 28th St SE',
#    'address2': '',
#    'address3': '',
#    'city': 'Kentwood',
#    'zip_code': '49512',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['3122 28th St SE', 'Kentwood, MI 49512']},
#   'phone': '+16162724135',
#   'display_phone': '(616) 272-4135',
#   'distance': 53401.67418325176},
#  {'id': '0QvIcjiKK-SgQR0k-SH4Iw',
#   'alias': 'deluxe-restaurant-and-bar-grand-rapids',
#   'name': 'Deluxe Restaurant & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Vj-m6lIfXTxQCQkFJb2dpQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/deluxe-restaurant-and-bar-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.8441312, 'longitude': -85.66406505480172},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '6597 Division Ave S',
#    'address2': '',
#    'address3': None,
#    'city': 'Grand Rapids',
#    'zip_code': '49548-7835',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['6597 Division Ave S', 'Grand Rapids, MI 49548-7835']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 50715.14161799402},
#  {'id': 'MIxulqY97wDNFNHq0d_3IA',
#   'alias': 'spice-of-india-grand-rapids',
#   'name': 'Spice of India',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sQVYSnqAqXuUkxjHxNuCPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spice-of-india-grand-rapids?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 18,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'grocery', 'title': 'Grocery'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.91228, 'longitude': -85.6347},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1310 28th St SE',
#    'address2': None,
#    'address3': None,
#    'city': 'Grand Rapids',
#    'zip_code': '49508',
#    'country': 'US',
#    'state': 'MI',
#    'display_address': ['1310 28th St SE', 'Grand Rapids, MI 49508']},
#   'phone': '+16162456654',
#   'display_phone': '(616) 245-6654',
#   'distance': 49999.22171336762}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                             alias  \
# 0   0pdd7dgAWqHVF17Qpj6zpQ          cumin-fresh-indian-kitchen-grand-haven-2
# 1   KZDRLMbnf-vPHEfiQMG6QA          cumin-fresh-indian-kitchen-grand-haven-3
# 2   ndCJfRFJ-FXv7oil2LVcwQ                            curry-kitchen-muskegon
# 3   TUTlORrbycnmJ2qteCnxEw                               naan-pizza-muskegon
# 4   Xqtu6fu0tjy_phPO3rm-_Q                pind-indian-cuisine-grand-rapids-2
# 5   6KrPfYLp7EHWXDEGzuA49Q                        indian-masala-grand-rapids
# 6   ZA6XOfhfgFSOGILxvXto1g  mithu-sri-lankan-and-indian-cuisine-grand-rapids
# 7   Rap8_CEtSey5Az4FnCtoVg                    palace-of-india-grand-rapids-3
# 8   QN8QMDuk9sjA61GyVAs_Fw                           curry-leaf-grand-rapids
# 9   2XT4I_AVi2-tC_Ys7PsfXA             karki-restaurant-and-bar-grand-rapids
# 10  rpJga5N1UMKt6-_z8egtXw                             desi-spice-kentwood-2
# 11  B0HGwB6jQwJns8e90Qt90Q                        little-africa-grand-rapids
# 12  kBZCdKEQmi7rL8nL_yjgQw                     curry-kitchen-gr-grand-rapids
# 13  GciiG0m-yRT5auUYBmyDGg                           india-town-grand-rapids
# 14  E1Otf4z6OCsw7B4JSKZn_A                 grand-indian-cuisine-grand-rapids
# 15  zdB3yM-2j6SROhuOZzcKEA                      pals-indian-cuisine-kentwood
# 16  xj4OAljKp5QvEzUt-RSkZA     steak-and-spice-by-curry-kitchen-grand-rapids
# 17  9Ol1HLkbMOBmuzgbDGVILA                               le-kabob-kentwood-3
# 18  0QvIcjiKK-SgQR0k-SH4Iw            deluxe-restaurant-and-bar-grand-rapids
# 19  MIxulqY97wDNFNHq0d_3IA                       spice-of-india-grand-rapids
#
#                                  name  \
# 0          Cumin Fresh Indian Kitchen
# 1          Cumin Fresh Indian Kitchen
# 2                       Curry Kitchen
# 3                          Naan Pizza
# 4                 Pind Indian Cuisine
# 5                       Indian Masala
# 6   Mithu Sri Lankan & Indian Cuisine
# 7                     Palace of India
# 8                          Curry Leaf
# 9              Karki Restaurant & Bar
# 10                         Desi Spice
# 11                      Little Africa
# 12                   Curry Kitchen GR
# 13                         India Town
# 14               Grand Indian Cuisine
# 15               Pal's Indian Cuisine
# 16     Steak & Spice By Curry Kitchen
# 17                           Le Kabob
# 18            Deluxe Restaurant & Bar
# 19                     Spice of India
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/132Cz0...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/rbWqXD...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/ykZIbe...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/pUjlIK...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/5fzDMm...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/m2jQ6g...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/YMcS-z...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/9TvKVU...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/RZe3Ir...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/88_EUD...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/0jVjz7...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/YHTw28...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/GHTw4M...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/yjaSbL...      False
# 14                                                         False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/CD3EYk...      False
# 16                                                         False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/9oZqpt...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/Vj-m6l...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/sQVYSn...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/cumin-fresh-indian-ki...            90
# 1   https://www.yelp.com/biz/cumin-fresh-indian-ki...             1
# 2   https://www.yelp.com/biz/curry-kitchen-muskego...           158
# 3   https://www.yelp.com/biz/naan-pizza-muskegon?a...             7
# 4   https://www.yelp.com/biz/pind-indian-cuisine-g...           134
# 5   https://www.yelp.com/biz/indian-masala-grand-r...           114
# 6   https://www.yelp.com/biz/mithu-sri-lankan-and-...            54
# 7   https://www.yelp.com/biz/palace-of-india-grand...           156
# 8   https://www.yelp.com/biz/curry-leaf-grand-rapi...           184
# 9   https://www.yelp.com/biz/karki-restaurant-and-...            12
# 10  https://www.yelp.com/biz/desi-spice-kentwood-2...            53
# 11  https://www.yelp.com/biz/little-africa-grand-r...           141
# 12  https://www.yelp.com/biz/curry-kitchen-gr-gran...           157
# 13  https://www.yelp.com/biz/india-town-grand-rapi...            80
# 14  https://www.yelp.com/biz/grand-indian-cuisine-...            10
# 15  https://www.yelp.com/biz/pals-indian-cuisine-k...           113
# 16  https://www.yelp.com/biz/steak-and-spice-by-cu...             1
# 17  https://www.yelp.com/biz/le-kabob-kentwood-3?a...           266
# 18  https://www.yelp.com/biz/deluxe-restaurant-and...             1
# 19  https://www.yelp.com/biz/spice-of-india-grand-...            18
#
#                                            categories  rating  \
# 0   [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.5
# 1   [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     5.0
# 2            [{'alias': 'indpak', 'title': 'Indian'}]     4.0
# 3   [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.5
# 4            [{'alias': 'indpak', 'title': 'Indian'}]     4.5
# 5            [{'alias': 'indpak', 'title': 'Indian'}]     4.5
# 6   [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     5.0
# 7            [{'alias': 'indpak', 'title': 'Indian'}]     4.0
# 8            [{'alias': 'indpak', 'title': 'Indian'}]     4.0
# 9   [{'alias': 'himalayan', 'title': 'Himalayan/Ne...     4.5
# 10  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.5
# 11  [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     4.5
# 12  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.0
# 13  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.0
# 14  [{'alias': 'kebab', 'title': 'Kebab'}, {'alias...     4.5
# 15           [{'alias': 'indpak', 'title': 'Indian'}]     4.0
# 16           [{'alias': 'indpak', 'title': 'Indian'}]     1.0
# 17  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.0
# 18  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.0
# 19  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.5
#
#                                           coordinates        transactions  \
# 0    {'latitude': 43.044243, 'longitude': -86.214143}            [pickup]
# 1   {'latitude': 43.0442582084732, 'longitude': -8...            [pickup]
# 2   {'latitude': 43.2315826416016, 'longitude': -8...  [delivery, pickup]
# 3   {'latitude': 43.2318587808138, 'longitude': -8...  [delivery, pickup]
# 4   {'latitude': 42.96338933, 'longitude': -85.674...  [delivery, pickup]
# 5      {'latitude': 42.91316, 'longitude': -85.52663}  [delivery, pickup]
# 6   {'latitude': 42.8850439571692, 'longitude': -8...          [delivery]
# 7   {'latitude': 42.9628487, 'longitude': -85.6649...  [delivery, pickup]
# 8   {'latitude': 42.883418302206, 'longitude': -85...  [delivery, pickup]
# 9   {'latitude': 42.88382960589625, 'longitude': -...  [delivery, pickup]
# 10    {'latitude': 42.881511, 'longitude': -85.60824}  [delivery, pickup]
# 11     {'latitude': 42.96255, 'longitude': -85.64509}            [pickup]
# 12     {'latitude': 42.99496, 'longitude': -85.67512}  [delivery, pickup]
# 13  {'latitude': 42.895907753757264, 'longitude': ...  [delivery, pickup]
# 14  {'latitude': 42.91228659999999, 'longitude': -...  [delivery, pickup]
# 15   {'latitude': 42.913036, 'longitude': -85.596093}  [delivery, pickup]
# 16  {'latitude': 42.912011357802115, 'longitude': ...                  []
# 17  {'latitude': 42.9120920396257, 'longitude': -8...  [delivery, pickup]
# 18  {'latitude': 42.8441312, 'longitude': -85.6640...  [delivery, pickup]
# 19      {'latitude': 42.91228, 'longitude': -85.6347}                  []
#
#    price                                           location         phone  \
# 0     $$  {'address1': '1106 Robins Rd', 'address2': '',...  +16164147591
# 1    NaN  {'address1': '1106 Robbins Rd', 'address2': ''...  +16164147591
# 2     $$  {'address1': '1133 3rd St', 'address2': '', 'a...  +12315719777
# 3      $  {'address1': '1131 3rd St', 'address2': '', 'a...  +12315719777
# 4     $$  {'address1': '241 Fulton St W', 'address2': ''...  +16168054767
# 5     $$  {'address1': '5769 28th St SE', 'address2': No...  +16162597394
# 6    NaN  {'address1': '4309 Kalamazoo Ave SE', 'address...  +16169565098
# 7     $$  {'address1': '138 Fulton St E', 'address2': ''...  +16169139000
# 8     $$  {'address1': '2222 44th St SE', 'address2': ''...  +16162814452
# 9    NaN  {'address1': '2293 44th St SE', 'address2': ''...  +16165511765
# 10   NaN  {'address1': '4445D Breton Rd', 'address2': No...  +16164273728
# 11     $  {'address1': '956 E Fulton St', 'address2': ''...  +16162221169
# 12    $$  {'address1': '270 Ann St NW', 'address2': '', ...  +16163637748
# 13    $$  {'address1': '3760 Division Ave S', 'address2'...  +16162431219
# 14   NaN  {'address1': '1280 28th St SE', 'address2': No...  +16167346197
# 15    $$  {'address1': '2887 28th St SE', 'address2': ''...  +16169572271
# 16   NaN  {'address1': '5700 28th St SE', 'address2': ''...  +16169571775
# 17    $$  {'address1': '3122 28th St SE', 'address2': ''...  +16162724135
# 18   NaN  {'address1': '6597 Division Ave S', 'address2'...
# 19     $  {'address1': '1310 28th St SE', 'address2': No...  +16162456654
#
#      display_phone      distance
# 0   (616) 414-7591    943.998333
# 1   (616) 414-7591    871.693627
# 2   (231) 571-9777  20114.112388
# 3   (231) 571-9777  20148.057514
# 4   (616) 805-4767  45338.760827
# 5   (616) 259-7394  58464.754276
# 6   (616) 956-5098  51648.473921
# 7   (616) 913-9000  46100.424687
# 8   (616) 281-4452  52932.761602
# 9   (616) 551-1765  53023.817720
# 10  (616) 427-3728  53164.104668
# 11  (616) 222-1169  47687.553106
# 12  (616) 363-7748  44670.983153
# 13  (616) 243-1219  48275.891559
# 14  (616) 734-6197  49944.052797
# 15  (616) 957-2271  52948.914894
# 16  (616) 957-1775  58477.147043
# 17  (616) 272-4135  53401.674183
# 18                  50715.141618
# 19  (616) 245-6654  49999.221713

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Import additional packages for controlling our loop
import time, math
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 2

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
   # The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
            
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location=location,
                                        term=term, 
                                        offset=n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])

        with open(JSON_FILE,'w') as f:
            json.dump(previous_results,f)
            
    #What to do if we get an error/exception.
    except Exception as e: # saving the error message so we can print it.
        print('[!] ERROR: ',e)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                        id                          alias             name  \
# 0  EA6Vr2YcvwVl5rIO0Sa29w  empire-buffet-comstock-park-2    Empire Buffet
# 1  1Q5StZN4uda1IzgJmY16wQ   two-beards-deli-grand-rapids  Two Beards Deli
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/vHFPuy...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/d4nzLg...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/empire-buffet-comstoc...            29
# 1  https://www.yelp.com/biz/two-beards-deli-grand...           254
#
#                                           categories  rating  \
# 0  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.0
# 1  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     4.5
#
#                                         coordinates        transactions price  \
# 0  {'latitude': 43.041552, 'longitude': -85.690212}  [pickup, delivery]     $
# 1     {'latitude': 42.9621, 'longitude': -85.66887}          [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '4255 Alpine Ave NW', 'address2':...  +16167858880
# 1  {'address1': '38 Commerce Ave SW', 'address2':...  +16167193802
#
#     display_phone      distance
# 0  (616) 785-8880  42950.055666
# 1  (616) 719-3802  45823.366817

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                     alias  \
# 0  KZDRLMbnf-vPHEfiQMG6QA  cumin-fresh-indian-kitchen-grand-haven-3
# 1  ndCJfRFJ-FXv7oil2LVcwQ                    curry-kitchen-muskegon
# 2  TUTlORrbycnmJ2qteCnxEw                       naan-pizza-muskegon
# 3  Xqtu6fu0tjy_phPO3rm-_Q        pind-indian-cuisine-grand-rapids-2
# 4  6KrPfYLp7EHWXDEGzuA49Q                indian-masala-grand-rapids
#
#                          name  \
# 0  Cumin Fresh Indian Kitchen
# 1               Curry Kitchen
# 2                  Naan Pizza
# 3         Pind Indian Cuisine
# 4               Indian Masala
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/rbWqXD...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/ykZIbe...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/pUjlIK...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/5fzDMm...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/m2jQ6g...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/cumin-fresh-indian-ki...             1
# 1  https://www.yelp.com/biz/curry-kitchen-muskego...           158
# 2  https://www.yelp.com/biz/naan-pizza-muskegon?a...             7
# 3  https://www.yelp.com/biz/pind-indian-cuisine-g...           134
# 4  https://www.yelp.com/biz/indian-masala-grand-r...           114
#
#                                           categories  rating  \
# 0  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     5.0
# 1           [{'alias': 'indpak', 'title': 'Indian'}]     4.0
# 2  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.5
# 3           [{'alias': 'indpak', 'title': 'Indian'}]     4.5
# 4           [{'alias': 'indpak', 'title': 'Indian'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 43.0442582084732, 'longitude': -8...            [pickup]
# 1  {'latitude': 43.2315826416016, 'longitude': -8...  [delivery, pickup]
# 2  {'latitude': 43.2318587808138, 'longitude': -8...  [delivery, pickup]
# 3  {'latitude': 42.96338933, 'longitude': -85.674...  [delivery, pickup]
# 4     {'latitude': 42.91316, 'longitude': -85.52663}  [delivery, pickup]
#
#                                             location         phone  \
# 0  {'address1': '1106 Robbins Rd', 'address2': ''...  +16164147591
# 1  {'address1': '1133 3rd St', 'address2': '', 'a...  +12315719777
# 2  {'address1': '1131 3rd St', 'address2': '', 'a...  +12315719777
# 3  {'address1': '241 Fulton St W', 'address2': ''...  +16168054767
# 4  {'address1': '5769 28th St SE', 'address2': No...  +16162597394
#
#     display_phone      distance price
# 0  (616) 414-7591    871.693627   NaN
# 1  (231) 571-9777  20114.112388    $$
# 2  (231) 571-9777  20148.057514     $
# 3  (616) 805-4767  45338.760827    $$
# 4  (616) 259-7394  58464.754276    $$

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Grand Haven-indian.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression='gzip', index=False)
